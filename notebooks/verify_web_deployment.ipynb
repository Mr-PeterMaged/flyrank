# %% [markdown]
# # Website deployment verification
#
# Peter Maged — static asset packaging, credits and external backend routes. This notebook checks only web deployment changes; it does not rerun unrelated research or access private datasets.

# %%
import subprocess, sys
result = subprocess.run([sys.executable, 'scripts/verify-deployment.py'], check=True, capture_output=True, text=True)
print(result.stdout)
# Out:
# PASS .: assets, routes, credits, configuration guards
# PASS portfolio: assets, routes, credits, configuration guards
# PASS paper: assets, routes, credits, configuration guards
# PASS todo-api: assets, routes, credits, configuration guards
# PASS background-job: assets, routes, credits, configuration guards
# PASS pdf-report-generator: assets, routes, credits, configuration guards
# PASS scraper: assets, routes, credits, configuration guards
# Seven deployment targets verified. No datasets or external services accessed.
